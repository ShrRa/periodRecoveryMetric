# %% [markdown]
# Calculate Kuiper metric for a given cadence for each point of the sky.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import healpy as hp

import rubin_sim.maf as maf
import rubin_sim.utils as rsUtils
from rubin_sim.data import get_baseline

from simcodes.fitters import ExtendedLS
from gatspy.periodic import LombScargleMultiband
from KuiperMetric import KuiperVS
from datetime import datetime

# %%
# Grab the current baseline file. Should have been downloaded with rubin_sim. 
# Can grab lots of different sims from: http://astro-lsst-01.astro.washington.edu:8081/
baseline_file = get_baseline()
name = os.path.basename(baseline_file).replace('.db','')
conn = maf.db.OpsimDatabase(baseline_file)

outDir = datetime.today().strftime('%d_%m_%Y_')+'temp'
resultsDb = maf.db.ResultsDb(outDir=outDir)

# %%
# Same for rolling cadence
rollDbFile = '/home/alex/rubin_sim_data/rolling_all_sky_ns2_rw0.9_v2.0_10yrs.db'
rollName = os.path.split(rollDbFile)[-1].replace('.db', '')
rollDb = maf.db.OpsimDatabase(rollDbFile)
resultsDbRoll = maf.db.ResultsDb(outDir=outDir)
print(rollName)
# Out:
# rolling_all_sky_ns2_rw0.9_v2.0_10yrs

# %%
# Set range of periods for which we're gonna build the maps
start=0.1
numPoints=500
totalObsLength=365*7

periods=np.round(np.geomspace(start,totalObsLength,numPoints),4)
bundleList=[]
bundleListRoll=[]
summary_metrics = [maf.MedianMetric()]
sql = ''
nside=2**5 # for HealpixSlicer
slicer = maf.HealpixSlicer(nside=nside)
for p in periods:
    metric = KuiperVS(period=p)
    
    bundleList.append(maf.MetricBundle(metric, slicer, sql, summaryMetrics=summary_metrics, 
                                       runName='KuiperMedian_'+str(p)))
    bundleListRoll.append(maf.MetricBundle(metric, slicer, sql, summaryMetrics=summary_metrics, 
                                           runName='RollKuiperMedian_'+str(p)))
# Out:
# Healpix slicer using NSIDE=32, approximate resolution 109.935565 arcminutes

# %%
bd = maf.metricBundles.makeBundlesDictFromList(bundleList)
bg = maf.metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database observations with no constraint for columns ['rotSkyPos', 'fieldRA', 'fieldDec', 'observationStartMJD'].
# Found 2086980 visits
# Running:  ['KuiperMedian_0_1_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1021_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1042_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1063_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1085_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1107_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_113_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1153_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1177_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1201_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1226_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1251_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1276_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1303_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1329_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1357_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1385_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1413_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1442_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1472_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1502_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1533_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1564_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1596_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1629_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1663_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1697_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1732_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1767_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1804_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1841_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1878_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1917_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1956_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_1997_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2038_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_208_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2122_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2166_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_221_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2256_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2302_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2349_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2398_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2447_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2497_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2549_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2601_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2654_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2709_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2765_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2821_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2879_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2938_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_2999_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_306_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3123_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3187_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3253_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_332_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3388_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3458_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3529_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3601_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3675_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3751_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3828_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3906_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_3987_KuiperVS_observationStartMJD_HEAL', 'KuiperMedian_0_4069_KuiperVS_observationStartMJD_HEAL', 'Kuiper ...
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
bdRoll = maf.metricBundles.makeBundlesDictFromList(bundleListRoll)
bgRoll = maf.metricBundles.MetricBundleGroup(bdRoll, rollDb, outDir=outDir, resultsDb=resultsDbRoll)
bgRoll.runAll()
# Out:
# Querying database observations with no constraint for columns ['rotSkyPos', 'fieldRA', 'fieldDec', 'observationStartMJD'].
# Found 2088105 visits
# Running:  ['RollKuiperMedian_0_1_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1021_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1042_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1063_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1085_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1107_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_113_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1153_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1177_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1201_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1226_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1251_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1276_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1303_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1329_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1357_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1385_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1413_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1442_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1472_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1502_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1533_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1564_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1596_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1629_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1663_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1697_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1732_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1767_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1804_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1841_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1878_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1917_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1956_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_1997_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2038_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_208_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2122_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2166_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_221_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2256_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2302_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2349_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2398_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2447_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2497_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2549_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2601_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2654_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2709_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2765_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2821_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2879_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2938_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_2999_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_306_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3123_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3187_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3253_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_332_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3388_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3458_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3529_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3601_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3675_KuiperVS_observationStartMJD_HEAL', 'RollKuiperMedian_0_3751_KuiperV ...
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
getMedianDict=lambda bList:[(float(p.runName.split('_')[1]),round(p.summaryValues['Median'],3)) for p in bList]
periods=pd.DataFrame(columns=['period','median Kuiper value'],data=getMedianDict(bundleList))
periodsRoll=pd.DataFrame(columns=['period','median Kuiper value'],data=getMedianDict(bundleListRoll))

# %%
fig,ax=plt.subplots(1,1,figsize=(15,3))
ax.scatter(periods['period'],periods['median Kuiper value'],s=2,label='baseline cadence')
ax.scatter(periodsRoll['period'],periodsRoll['median Kuiper value'],marker='s',s=2,label='rolling cadence')
i=0
while i<totalObsLength:
    i+=365
    ax.axvline(i,color='r',alpha=0.4)
ax.legend()
ax.set_xlabel('Period in days')
ax.set_ylabel('Median Kuiper metric')
# Out:
# Text(0, 0.5, 'Median Kuiper metric')

# %%
fig,ax=plt.subplots(1,1,figsize=(15,3))
ax.scatter(periods['period'],periods['median Kuiper value'],s=2,label='baseline cadence')
ax.scatter(periodsRoll['period'],periodsRoll['median Kuiper value'],marker='s',s=2,label='rolling cadence')
i=0
while i<totalObsLength:
    i+=365
    ax.axvline(i,color='r',alpha=0.4)
ax.legend()
ax.set_xlabel('Period in days')
ax.set_ylabel('Median Kuiper metric')
ax.set_xlim(0,200)
ax.set_ylim(0,max(list(periods['median Kuiper value'])[:200])+0.02)
# Out:
# (0.0, 0.315)

# %%
fig,ax=plt.subplots(1,1,figsize=(15,3))
ax.scatter(periods['period'],periods['median Kuiper value'],s=2,label='baseline cadence')
ax.scatter(periodsRoll['period'],periodsRoll['median Kuiper value'],marker='s',s=2,label='rolling cadence')
i=0
while i<totalObsLength:
    i+=365
    ax.axvline(i,color='r',alpha=0.4)
ax.legend()
ax.set_xlabel('Period in days')
ax.set_ylabel('Median Kuiper metric')
ax.set_xlim(0,2)
ax.set_ylim(min(list(periods['median Kuiper value'])[:2])-0.02,max(list(periods['median Kuiper value'])[:2])+0.05)
# Out:
# (0.028, 0.116)

# %%
cadenceComparison=pd.DataFrame(columns=['period min','period max',
                                        'baseline median Kuiper','rolling median Kuiper'])


d={'period min':0.1,'period max':1,
      'baseline median Kuiper':periods[(periods['period']>0.1) & 
                                    (periods['period']<=1)]['median Kuiper value'].median().round(3),
      'rolling median Kuiper':periodsRoll[(periodsRoll['period']>0.1) & 
                                    (periodsRoll['period']<=1)]['median Kuiper value'].median().round(3)}
cadenceComparison=cadenceComparison.append(d,ignore_index=True)

for i in range(1,totalObsLength,365):
    d={'period min':i,'period max':i+365,
      'baseline median Kuiper':periods[(periods['period']>i) & 
                                    (periods['period']<=i+365)]['median Kuiper value'].median().round(3),
      'rolling median Kuiper':periodsRoll[(periodsRoll['period']>i) & 
                                    (periodsRoll['period']<=i+365)]['median Kuiper value'].median().round(3)}
    cadenceComparison=cadenceComparison.append(d,ignore_index=True)
cadenceComparison
# Out:
#    period min  period max  baseline median Kuiper  rolling median Kuiper
# 0         0.1         1.0                   0.058                  0.058
# 1         1.0       366.0                   0.072                  0.073
# 2       366.0       731.0                   0.131                  0.132
# 3       731.0      1096.0                   0.201                  0.205
# 4      1096.0      1461.0                   0.167                  0.172
# 5      1461.0      1826.0                   0.192                  0.194
# 6      1826.0      2191.0                   0.170                  0.173
# 7      2191.0      2556.0                   0.238                  0.238
